# %% [markdown]
# # STA130 HW07 — 14 November, 2024
#
# ### Andrew Pols
#
# ___

# %% [markdown]
# # 1. Conceptual Definitions

# %% [markdown]
# ### 1.1 The difference between Simple Linear Regression and Multiple Linear Regression; and the benefit the latter provides over the former:
#
# Multiple Linear Regression (MLR) extends the concept of Simple Linear Regression by incorporating multiple predictor variables to model the outcome variable. The model is represented by an equation similar to the SLR model, but with additional terms for each variable:
#
# $$ \large Y_i = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \cdots + \beta_i x_i$$
#
# Here, we interpret $\beta_0$ as the intercept of the line modelling the **continuous** outcome variable. (Note that in alignment with the course notes, we will assume the $\epsilon$ term to be present without writing it, for simplicity).
#
# MLR can offer a more realistic model by considering multiple factors that might influence an outcome; it can be unreasonable to assume just ONE predictor influences the outcome, so MLR takes the idea of SLR and extends it to multiple influences, and allows us to compare the strengths of those influences on the outcome.
#
# We will discuss further categorical and continuous variations of the above equation in the following answers.
#
#
# $$ \large Y_i = \beta_0 + \beta_1 1_\text{[group]}k_i + \beta_2 1_\text{[group]}k_i + \cdots + \beta_i 1_\text{[group]}k_i $$
#
# __

# %% [markdown]
# ### 1.2: the difference between using a continuous variable and an indicator variable in Simple Linear Regression; and these two linear forms:
#
# The continuous form of Simple Linear Regression takes on the equation:
#
# $$ \large Y_i = \beta_0 + \beta_1 x_1$$
#
# The categorical indicator variable form of SLR takes on the equation:
#
# $$ \large Y_i = \beta_0 + \beta_1 \times 1_\text{[group]} k_i $$
#
# In the continuous variable model, the slope coefficient $\beta_1$ is the average change in the outcome variable for a one-unit increase in the **continuous** predictor variable. The $\beta_0$ term is the y-intercept of the line that is modelled; this is simply a vertical translation of the line, or can also be thought of as the value of $Y_i$ when $x_i = 0$.
#
# In the indicator model, we deal with categorical predictor variables instead of continuous ones. Thus, we are no longer dealing in terms of slopes and intercepts, but baselines and contrasts. The baseline of the model is $\beta_0$, whereas the contrast is $\beta_1$. For a categorical variable, $k$, if $k_i$ satisfies the desired group (ie. $k_i \in \text{group}$), then the contrast variable $\beta_1$ is "turned on." So, the average of such variables is $\beta_0 + \beta_1$. Conversely, the average of predictor variables that don't satisfy the group condition have an average of $\beta_0$. So, the difference between these two averages is $\beta_1$; hence, the name "contrast" variable.
#
# So, the indicator model helps find the difference in categories of a predictor variable.
#
# __

# %% [markdown]
# ### 1.3: the change that happens in the behavior of the model (i.e., the expected nature of the data it models) when a single indicator variable is introduced alongside a continuous variable to create a Multiple Linear Regression; and these two linear forms (i.e., the Simple Linear Regression versus the Multiple Linear Regression):
#
# When modelling an indicator variable with a continuous variable, we obtain the following equation:
#
# $$ \large Y_i = \beta_0 + \beta_1 \times 1_\text{[group]} k_i + \beta_2 z_i $$
#
# In this model, we have a combined explanation of categorical comparison and continuous effects. That is, we still retain the same properties in which $\beta_0$ is the ***baseline***, but now we have two different types of coefficients. In the aboce equation, we have a categorical variable $k_i$, in which a $k_i$ satisfying a given group is applied a contrast of $\beta_1$. However, we now also have a slope coefficient of $\beta_2$.
#
# This means that we form two parallel lines with the same slope $\beta_2$. The lines will differ by a vertical translation of $\beta_1$, since this is the contrast between the two groups being studied. We can extend this idea to more variables, as outlined below.

# %% [markdown]
# ### 1.4: the effect of adding an interaction between a continuous and an indicator variable in Multiple Linear Regression models; and this linear form:
#
# The model in 1.3 accounts for a constant slope between groups, producing parallel lines. But, what if we wanted to see the continuous effect of a group on the outcome? We may add the below interaction:
#
# $$ \large Y_i = \beta_0 + \beta_1 x_i + \beta_2 \times 1_{[\text{group}]}(k_i) + \beta_3 \times x_i \times 1_{[\text{group}]}(k_i)$$
#
# Thus, by adding the indicator "switch" to a multiplication of a slope coefficient, we can adjust each group's slope accordingly.
#
# For variables not satisfying the group condition (ie. $k_i = 0$), we get $Y_i = \beta_0 + \beta_1 x_i$,
# Otherwise, for variables satisfying the group condition, we get $ Y_i = \beta_0 + \beta_1 x_i + \beta_2 \times 1_{[\text{group}]}(k_i) + \beta_3 \times x_i \times 1_{[\text{group}]}(k_i)$.
#
# The first line has intercept $\beta_0$ and slope $\beta_1$. The second line has intercept $\beta_0 + \beta_2$ and slope $\beta_1 + \beta_3$.
#
# Thus, this interaction allows us to have differnet slopes depending on the group term, providing a dynamic modelling of predictors to outcomes.

# %% [markdown]
# ### 1.5: the behavior of a Multiple Linear Regression model (i.e., the expected nature of the data it models) based only on indicator variables derived from a non-binary categorical variable; this linear form; and the necessarily resulting binary variable encodings it utilizes:
#
# The previous answers addressed binary categorical variables, in which we either satisfy a condition, or we don't. For categories with multiple responses, we can actually employ the same methodology. So, for one "group" of categories, we have one choice of the group as the baseline, with the rest of the group as the references to that baseline (meaning we have to add indicator variables to make this reference).
#
# The following is the linear form of the model:
#
# $$Y_i = \beta_0 + \sum_{j=1}^{K-1} \beta_j \times 1_{[\text{Category j}]}(k_i)$$
#
# As we see below, we have K-1 indicator variables, where K is the number of categories in a "group" of predictor variables. The "unaccounted" variable is represented by $\beta_0$. Thus, every other category is a reference to this baseline. This is done by this "binary encoding" that flips an associated $k_i$ **on or off** (binary) depending on the satisfaction of a condition.

# %% [markdown]
# ## NotebookLM Session Summary
#
#
#
#
# The conversation focused on understanding simple and multiple linear regression and the use of continuous and indicator variables in both.  It began by comparing SLR, which models the relationship between one predictor and an outcome, to MLR, which allows for multiple predictors. The discussion then explored the use of continuous variables as predictors in both SLR and MLR. The conversation then turned to non-binary categorical variables, and how they can be represented in MLR using indicator variables, each representing a specific category except for the baseline category. This representation helps to understand the differences in the outcome variable across various categories relative to the chosen baseline. The coefficients associated with these indicator variables then quantify the average difference in the outcome variable between the represented category and the baseline. To provide a more complete mathematical understanding, the conversation also touched upon the generalized form of MLR, both with sigma notation, which provides a precise mathematical representation, and without sigma notation for a more intuitive understanding. The conversation concluded by using a concrete example of house prices and regions to illustrate these concepts.
#
#
#
# ___

# %% [markdown]
# # 2. Multiple Linear Regression Example Discussion

# %% [markdown]
# ### 2.1
#
# Let Sales be the outcome variable, predicted by continuous variables TV and Online, which we will call $x$ and $z$ respectively.
#
# Without any interaction between variables, we obtain the following model from the scenario:
#
# $$ \text{Sales} = \beta_0 + \beta_1 x_i + \beta_2 z_i $$
#
# Thus, we observe that sales are predicted independently and ***continuously*** by each predictor variable. That is, the coefficients of each predictor is unaffected by the other.
#
# However, if we wanted an interaction between the two, we could have a "weighted" affect by adding an additional term that quantifies the combined effect of both predictor variables at the same time:
#
# $$ \text{Sales} = \beta_0 + \beta_1 x_i + \beta_2 z_i + \beta_3 x_i z_i$$
#
# Intuitively, we can characterize this 3rd term as being a syngergistic effect between the two variables; if $x_i$ is large, but $z_i$ is small, then the effect of $x_i$ is diminished (and vice versa). But if both variables are large, their combined effect will be even greater.

# %% [markdown]
# ### 2.2
#
# In the case of categorical variables, we may categorize the predictor variables as being "High" or "Not High" (ie. low) for the purpose of creating binary varibales. The linear form of this model becomes:
#
# $$ \large \text{Sales} = \beta_0 + \beta_1 \times 1_\text{[High]} x_i + \beta_2 \times 1_\text{[High]}z_i$$
#
# In this case, $\beta_0$ is the baseline, which occurs when TV and Online budgets are BOTH low.
#
# When TV budget is high, but Online budgets are low, we add the contrast $\beta_1$, for an average of $\beta_0 + \beta_1$.
#
# When Online Budget is high, but TV budget is low, we add the contrast $\beta_2$, for an average of $\beta_0 + \beta_2$.
#
#
# However, this isnt particularly nuanced, as each variable is independent and does not affect the other. We can add a synergestic interaction between them by the following equation:
#
# $$ \large \text{Sales} = \beta_0 + \beta_1 \times 1_\text{[High]} x_i + \beta_2 \times 1_\text{[High]}z_i + \beta_3 \times 1_\text{[High]} x_i z_i$$.
#
# Similarly to the explanation in 2.1, the effect here is synergestic in the last term. This means that the effects of the variables are combined. Since we're dealing with categorical variables, for the last term to be activated BOTH TV and Online budgets must be high, but this model allows us to see WHAT effect this has in this case (which is intuitively more telling...).

# %% [markdown]
# __
#
# ## NotebookLM Session Summary
# This conversation began by analyzing a hypothetical scenario of a company selling sports equipment and examining the relationship between sales and advertising spending on TV and online platforms.  The initial focus was on identifying the outcome variable (sales) and the predictor variables (TV and online advertising spending), and recognizing the potential for an interaction effect between these predictors. The discussion then shifted to formulating linear models, both with and without interaction terms, to represent the relationship between the variables. These linear models were expressed using mathematical formulas, considering both continuous and categorical representations of the predictor variables. For example, with continuous predictors, *Sales* = β<sub>0</sub> + β<sub>1</sub>&#x20; *TV* + β<sub>2</sub>&#x20; *Online* represents a model without interaction, while *Sales* = β<sub>0</sub> + β<sub>1</sub>&#x20; *TV* + β<sub>2</sub>&#x20; *Online* + β<sub>3</sub>&#x20; *TV* \* *Online* incorporates an interaction term. A key point of clarification involved the distinction between multiple predictor variables and indicator variables, emphasizing that indicator variables are specifically used to represent categorical variables in regression models. The conversation concluded by reiterating the importance of selecting the appropriate type and number of variables (continuous or indicator) based on the nature of the data and the relationships being modeled.
#
# ___

# %% [markdown]
# # 3. CSCH Logistic Regression

# %% [markdown]
# ### 3.1.
#
# Firstly, we will create an additive linear (logistic) regression based on the following variables.
#
# **Outcome:** WELLNESS_self_rated_mental_health_binary (a binary variable which we encode to either be "good" or "bad").
#
# **Predictors**: DEMO_age (continuous age variable), CONNECTION_community_barriers_introvert_binary (binary indicator variable of self-reported introvert vs. extrovert), CONNECTION_community_involvement_sports_p3m_binary (binary indicator variable reporting a person's sports activity level).
#
# If this were linear regression, it would look like this:
#
# $$ \large Y_i = \beta_0 + \beta_1 z_\text{age} + \beta_2 \times 1_\text{["introvert"]}k_i + \beta_3 \times 1_\text{["sporty"]}k_i$$
#
# The below code sets up and creates our model.

# %%
import pandas as pd
cols = pd.read_csv("../course_project/data/var_names.csv")

data = pd.read_csv("../course_project/data/CSCS_data_anon.csv", 
                   na_values=["9999", "", " ", "Presented but no response", "NA"],
                   low_memory=False)  # Specify the desired type


empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

data = data[data.REMOVE_case=='No']

data = data[data.SURVEY_collection_year==2022]

data.shape
# Out:
# (3896, 1779)

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np

# Binary mapping for WELLNESS_self_rated_mental_health
data.loc[:, 'WELLNESS_self_rated_mental_health_binary'] = data['WELLNESS_self_rated_mental_health'].map({
    'Poor': 0,
    'Fair': 0,
    'Good': 1,
    'Very good': 1,
    'Excellent': 1
})

# Define binary mapping for the introvert indicator
introvert_mapping = {
    'I am an introvert': 1,
    'Not Selected': 0,
    np.nan: 0  # Convert NaN values to 0
}

# Apply mapping to create binary column
data.loc[:, 'CONNECTION_community_barriers_introvert_binary'] = \
    data['CONNECTION_community_barriers_introvert'].map(introvert_mapping)

# Define the mapping for sports involvement
sports_mapping = {
    "Yes": 1,
    "No, but I would like to": 0,
    "No, and I'm not interested in doing so": 0,
    np.nan: 0  # Treat NaNs as "not interested"
}

# Apply the mapping to create the binary column
data.loc[:, 'CONNECTION_community_involvement_sports_p3m_binary'] = data['CONNECTION_community_involvement_sports_p3m'].map(sports_mapping)

# Ensure there are no NaNs in the outcome variable and predictors
data = data.dropna(subset=['WELLNESS_self_rated_mental_health_binary', 'CONNECTION_community_involvement_sports_p3m_binary', 'CONNECTION_community_barriers_introvert_binary', 'DEMO_age'])

# %%
# Define the logistic regression formula
formula_additive = 'WELLNESS_self_rated_mental_health_binary ~ DEMO_age + CONNECTION_community_barriers_introvert_binary + CONNECTION_community_involvement_sports_p3m_binary'

# Fit the logistic regression model
model_additive = smf.logit(formula=formula_additive, data=data).fit()

# Print the model summary
print(model_additive.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.626938
#          Iterations 6
#                                       Logit Regression Results
# ...
# Dep. Variable:     WELLNESS_self_rated_mental_health_binary   No. Observations:                 3148
# Model:                                                Logit   Df Residuals:                     3144
# Method:                                                 MLE   Df Model:                            3
# Date:                                      Fri, 15 Nov 2024   Pseudo R-squ.:                 0.01182
# Time:                                              17:35:12   Log-Likelihood:                -1973.6
# converged:                                             True   LL-Null:                       -1997.2
# Covariance Type:                                  nonrobust   LLR p-value:                 3.107e-10
# ...

# %% [markdown]
# ### 3.2.
# Leaving the above for later interpretation, we move on to a synergistic form of regression.
#
# The form of this model will have an interaction between (1) age and reported introversion, as well as (2) age and reported sport activity.
#
# The below equation models this:
#
# $$ \large Y_i = \beta_0 + \beta_1 z_{\text{age}} + \beta_2 \times 1_{\text{["introvert"]}}k_i + \beta_3 \times 1_{\text{["sporty"]}}k_i + \beta_4 \left( z_{\text{age}} \times 1_{\text{["introvert"]}}k_i \right) + \beta_5 \left( z_{\text{age}} \times 1_{\text{["sporty"]}}k_i \right)
# $$

# %%
# Synergistic model formula with main effects and interaction terms
formula_synergistic = (
    'WELLNESS_self_rated_mental_health_binary ~ '
    'DEMO_age + CONNECTION_community_barriers_introvert_binary + '
    'CONNECTION_community_involvement_sports_p3m_binary + '
    'DEMO_age:CONNECTION_community_barriers_introvert_binary + '
    'DEMO_age:CONNECTION_community_involvement_sports_p3m_binary'
)

# Fit the model
model_synergistic = smf.logit(formula=formula_synergistic, data=data).fit()

# Display the model summary
print(model_synergistic.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.626839
#          Iterations 6
#                                       Logit Regression Results
# ...
# Dep. Variable:     WELLNESS_self_rated_mental_health_binary   No. Observations:                 3148
# Model:                                                Logit   Df Residuals:                     3142
# Method:                                                 MLE   Df Model:                            5
# Date:                                      Fri, 15 Nov 2024   Pseudo R-squ.:                 0.01198
# Time:                                              17:35:12   Log-Likelihood:                -1973.3
# converged:                                             True   LL-Null:                       -1997.2
# Covariance Type:                                  nonrobust   LLR p-value:                 3.807e-09
# ...

# %% [markdown]
# ### 3.3.
#
# As noted above, the additive model is as follows:
# $ \;\; Y_i = \beta_0 + \beta_1 z_\text{age} + \beta_2 \times 1_\text{["introvert"]}k_i + \beta_3 \times 1_\text{["sporty"]}k_i$
#
# **Intuitive Explanation:**
# - $\beta_0$: The intercept, or baseline, outcome when age = 0, and a person is not introverted or sporty.
# - $\beta_1$: The slope coefficient of age; measures the rate of change of the outcome for each 1-year increase in age.
# -$\beta_2$: The contrast term between introverts and extroverts, levaraging binary encoding (purely additive; has no effect on age/sportiness).
# - $\beta_3$: The contrast term between sporty vs non-sporty people.
#
# __
#
# As noted above, the synergistic model is as follows:
# $ Y_i = \beta_0 + \beta_1 z_{\text{age}} + \beta_2 \times 1_{\text{["introvert"]}}k_i + \beta_3 \times 1_{\text{["sporty"]}}k_i + \beta_4 \left( z_{\text{age}} \times 1_{\text{["introvert"]}}k_i \right) + \beta_5 \left( z_{\text{age}} \times 1_{\text{["sporty"]}}k_i \right)
# $
#
# **Intuition:**
# - This has the same interpretation as the additive model, but also assumes interaction between predictors.
# - As explained in Q2, these interactions result in one predictor having a dependent impact on the effect of another.
# - In the synergistic model, being both "sporty" and "introverted" might have a stronger or weaker combined effect, not just the sum of their individual effects.

# %% [markdown]
# ### 3.4.
# In the additive model, we obtain the following results:
#
# - DEMO_age seems to have a slightly negative slope-coefficient of -0.0040, but with a p-value of 0.069, there is no evidence to suggest this is not just random chance (ie. can't reject $H_0$).
#
#
# - CONNECTION_community_barriers_introvert_binary seems to have a negative contrast term of -0.8260. This means that, on average, introverts tend to be slightly less content in terms of their mental health compared to the extrovert baseline. With a p-value of 0.00, we have extremely strong evidence against $H_0$.
#
#
# - CONNECTION_community_involvement_sports_p3m_binary seems to have a positive contrast of 1.2777. This means that, on average, sporty people tend to be slightly more content in their mental health compared to the non-sporty baseline. With a p-value of 0.00, we have extremely strong evidence against $H_0$.
#
#
# In the synergistic model, we obtain the following results:
# - DEMO_age, CONNECTION_community_barriers_introvert_binary, and CONNECTION_community_involvement_sports_p3m_binary on their own have about the same coefficient values.
#     - However, since we've added the effect of more interactions, the statistical evidence of the latter two predictors has decreased, with o-values of 0.032 and 0.037 respectively (although this is still enough evidence to reject $H_0$).
#
# <br>
#
# - For the interaction between DEMO_age:CONNECTION_community_barriers_introvert_binary, we observe a slightly positive coefficient of 0.0070. That is, on average, as age increases by one year, the log odds of the outcome occurring increase by 0.0070 more than they would for non-introverts.
#     - However, with a p-value of 0.506, we cannot reject $H_0$ — not statistically significant.
#
# <br>
#
#
# - For the interaction between DEMO_age:DEMO_age:CONNECTION_community_involvement_sports_p3m_binary, we observe a slightly negative coefficient of -0.0081. That is, on average, as age increases by one year, the log odds of the outcome occurring decrease by -0.0080 more than they would for non-sporty people.
#     - However, with a p-value of 0.625, we cannot reject $H_0$ — not statistically significant.

# %% [markdown]
# ### 3.5.

# %%
import plotly.graph_objects as go

# Create the additive model plot
fig_additive = go.Figure()

# Plot the actual data points (single color for all)
fig_additive.add_trace(go.Scatter(
    x=data['DEMO_age'], 
    y=data['WELLNESS_self_rated_mental_health_binary'],  # Actual data points (binary outcome)
    mode='markers',  # Only plot points (no line)
    name='Actual Data',
    marker=dict(color='blue', size=8)  # Set a single color for actual data
))

# Plot predicted probabilities for the additive model (single color for predicted data)
fig_additive.add_trace(go.Scatter(
    x=data['DEMO_age'], 
    y=model_additive.fittedvalues,  # Predicted probabilities
    mode='markers',  # Only plot points (no line)
    name='Predicted Probabilities',
    marker=dict(color='green', size=8)  # Set a single color for predicted data
))

# Update layout with title and axis labels
fig_additive.update_layout(
    title="Additive Model - Age vs. Mental Health (Sportiness & Introversion Included)",
    xaxis_title="Age (Implicit Predictors: Sportiness & Introversion)",
    yaxis_title="Predicted Probability of Higher Mental Health",
    showlegend=True,
    width=1000,
    height=600
)


# Display the plot
fig_additive.show(renderer='png')

# %%
# Synergistic model plot
fig_synergistic = go.Figure()

# Plot the data points for the outcome (1s and 0s)
fig_synergistic.add_trace(go.Scatter(x=data['DEMO_age'], y=data['WELLNESS_self_rated_mental_health_binary'], 
                                    mode='markers', name='Actual Data (Synergistic)',
                                    marker=dict(color='blue', size=8)))

# Add predicted probabilities for the synergistic model
fig_synergistic.add_trace(go.Scatter(x=data['DEMO_age'], y=model_synergistic.fittedvalues, 
                                    mode='markers', name='Predicted Probabilities (Synergistic)',
                                    marker=dict(color='red', size=8)))

# Add titles and axis labels
fig_synergistic.update_layout(
    title="Synergistic Model - Age vs. Mental Health (Sportiness & Introversion Included)",
    xaxis_title="Age (Implicit Predictors: Sportiness & Introversion)",
    yaxis_title="Predicted Probability of Higher Mental Health",
    showlegend=True,
    width=1000,
    height=600
)

fig_synergistic.show(renderer='png')

# %%
# Overlay plot with both additive and synergistic models
fig_overlay = go.Figure()

# Plot the data points for the outcome (1s and 0s)
fig_overlay.add_trace(go.Scatter(x=data['DEMO_age'], y=data['WELLNESS_self_rated_mental_health_binary'], 
                                mode='markers', name='Actual Data', marker=dict(color='blue', size=8)))

# Add predicted probabilities for the additive model
fig_overlay.add_trace(go.Scatter(x=data['DEMO_age'], y=model_additive.fittedvalues, 
                                mode='markers', name='Predicted Probabilities (Additive)', 
                                marker=dict(color='green', size=8)))

# Add predicted probabilities for the synergistic model
fig_overlay.add_trace(go.Scatter(x=data['DEMO_age'], y=model_synergistic.fittedvalues, 
                                mode='markers', name='Predicted Probabilities (Synergistic)', 
                                marker=dict(color='red', size=8)))

# Add titles and axis labels
fig_overlay.update_layout(
    title="Overlay of Additive and Synergistic Models - Age vs. Mental Health (Sportiness & Introversion Included)",
    xaxis_title="Age (Implicit Predictors: Sportiness & Introversion)",
    yaxis_title="Predicted Probability of Higher Mental Health",
    showlegend=True,
    width=1000,
    height=600
)

fig_overlay.show(renderer='png')

# %% [markdown]
# ### Interpretation
#
# The plot shows the relationship between age and the probability of having a higher self-rated mental health score (binary outcome: 1 for higher mental health, 0 for lower).
#
# - **Actual Data**: The blue markers represent the observed outcomes (1s and 0s) for each individual's age.
# - **Additive Model**: The green markers indicate the predicted probabilities based on the additive logistic regression model, which considers age, sportiness, and introversion status separately.
# - **Synergistic Model**: The red markers represent the predicted probabilities from the synergistic model, which includes an interaction term between age, sportiness, and introversion status.
#
# The predicted probabilities are continuous values between 0 and 1, reflecting the likelihood of a higher self-rated mental health score as age increases, under both models. The synergy between age and introversion status is captured more explicitly in the red markers.

# %% [markdown]
# __
# ## ChatGPT Session Summary
# https://chatgpt.com/share/6736b7d7-5668-800e-a35a-afe6ce05b972
#
# Over the course of our interactions, we discussed the process of fitting logistic regression models with binary predictors and visualizing the results. The focus was on interpreting additive and synergistic models, where the outcome was a binary mental health rating, influenced by age and introversion status. After addressing various issues with model fitting and plot formatting, I provided a step-by-step approach to visualize the data, first through individual plots for each model, followed by an overlay of both models for comparison. The discussion involved ensuring the plots used points instead of lines and involved making appropriate adjustments to clarify the results, focusing on simplicity and clarity for interpretation.
#
# ___

# %% [markdown]
# # 4. Statistical Evidence: R-Squared vs. P-Values

# %% [markdown]
# Consider the following code.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        17:35:14   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Conceptual Explanations
#
# We often treat p-values and $R^2$ as similar evidences of a combined purpose in the context of regression analysis. However, it is not true that both of them tell the same story, or that they both must have a "statistically significant" result to "confirm" each other.
#
#
# The apparent contradiction between the two statements comes from the different things that **R-squared** and **p-values** represent in regression analysis.
#
# **R-squared** shows how much of the variability in the outcome variable is explained by the model. In this case, a value of **17.6%** means that the model explains only a small portion of the total variability in the data. While the model does capture some key relationships, it suggests that other factors not included in the model may also play a significant role in affecting the outcome.
#
# **P-values**, on the other hand, test whether the effect of each predictor variable is statistically significant. A **low p-value** indicates that there is strong evidence against the null hypothesis (which suggests no effect), meaning the predictor has a **meaningful relationship** with the outcome, controlling for other variables in the model.
#
# However, ***these two concepts ARE NOT MUTUALLY EXCLUSIVE***.
#
# These concepts don't conflict; instead, they focus on different aspects of the model:
#
# - **R-squared** tells us about the overall goodness of fit—**how well the model explains the variation in the outcome**.
#
# - **P-values**, however, show us the strength of evidence for the relationship between each predictor and the outcome, **independent of the model’s overall explanatory power**.
#
# It’s completely possible for a model to have a low **R-squared** (indicating limited explanatory power) and still have **statistically significant coefficients** with **large effect sizes**. This means that while the predictors in the model have **strong individual effects** on the outcome, there could be other factors outside of the model that account for a significant portion of the outcome's variability. So, **both measures can be interpreted meaningfully together** because they focus on different aspects of the model's performance and the predictors' relationships with the outcome.

# %% [markdown]
# ## Example Explanation
#
# - **R-squared = 17.6%** means the model explains only a small portion (17.6%) of the variability in the outcome, **suggesting there are other unmeasured factors** contributing to the remaining 82.4% of the variation.
#
# - **Large coefficients with low p-values** indicate that the predictors included in the model have a **significant relationship** with the outcome and **contribute meaningfully** to predicting the outcome variable.
#
# In summary, the model captures some of the variability in the outcome, but **not enough to fully explain it**. Despite the low **R-squared**, the predictors are still **important** and have a **strong effect** on the outcome, as shown by their **large coefficients** and **low p-values**.
#
# This isn't contradictory because **R-squared** and **p-values** measure different aspects of the model: **R-squared** shows how much of the outcome's variability is explained by the model, while **p-values** indicate the significance of each predictor's relationship with the outcome, regardless of the model's overall explanatory power.

# %% [markdown]
# __
#
# ## NotebookLM Session Summary
# The discussions focused on clarifying the relationship between p-values and R-squared in statistical models. While not contradictory, these metrics address different aspects of model evaluation. P-values assess the statistical significance of individual predictor variables, indicating the probability of observing the estimated coefficient if there were no real association. R-squared, on the other hand, measures the model's overall goodness of fit, representing the proportion of variation in the outcome variable explained by the model. It is possible to have statistically significant predictors (low p-values) even with a low R-squared, suggesting that while individual predictors may have a real effect, the model as a whole does not account for much of the outcome variability. This can occur due to omitted variables, weak relationships, or a small sample size. The relative importance of p-values and R-squared depends on the analysis goals, with prediction tasks often prioritizing R-squared and causal inference focusing on p-values and coefficient interpretation. Ultimately, both metrics are important for a balanced evaluation of a model's strengths and limitations.
#
# ___

# %% [markdown]
# # 5. Regression and $R^2$ Revisited

# %% [markdown]
# Consider the five cells of code below, for which I will breifly describe what each of them is doing, and then provide a final overall explanation at the end.

# %% [markdown]
# ## Cell 1
# In this step, the dataset (`pokeaman`) is divided into two parts: a training set and a testing set, with each receiving 50% of the data. To ensure smooth analysis, missing values in the "Type 2" column are replaced with the string `'None'`, avoiding errors due to NaN values. The `train_test_split` function is used to separate the data, which allows the model to be trained on one part of the data and tested on another. This split is crucial for evaluating how well the model can generalize to new, unseen data, giving a better understanding of its overall performance.

# %%
import numpy as np
from sklearn.model_selection import train_test_split

fifty_fifty_split_size = int(pokeaman.shape[0]*0.5)

# Replace "NaN" (in the "Type 2" column with "None")
pokeaman.fillna('None', inplace=True)

np.random.seed(130)
pokeaman_train,pokeaman_test = \
  train_test_split(pokeaman, train_size=fifty_fifty_split_size)
pokeaman_train
# Out:
#        #                     Name   Type 1   Type 2  HP  Attack  Defense  \
# 370  338                  Solrock     Rock  Psychic  70      95       85
# 6      6                Charizard     Fire   Flying  78      84       78
# 242  224                Octillery    Water     None  75     105       75
# 661  600                    Klang    Steel     None  60      80       95
# 288  265                  Wurmple      Bug     None  45      45       35
# ..   ...                      ...      ...      ...  ..     ...      ...
# 522  471                  Glaceon      Ice     None  65      60      110
# 243  225                 Delibird      Ice   Flying  45      55       45
# 797  720      HoopaHoopa Confined  Psychic    Ghost  80     110       60
# 117  109                  Koffing   Poison     None  40      65       95
# 409  373  SalamenceMega Salamence   Dragon   Flying  95     145      130
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Cell 2
#
# This step defines a linear regression model using the formula `'HP ~ Attack + Defense'`, where `HP` is predicted based on `Attack` and `Defense` from the training data (`pokeaman_train`). The `fit()` function is used to estimate the coefficients of the predictors. After fitting the model, a summary is generated, which provides the coefficients for `Attack` and `Defense`, R-squared (indicating how well the model fits the data), and p-values (to test the statistical significance of the predictors).

# %%
model_spec3 = smf.ols(formula='HP ~ Attack + Defense', 
                      data=pokeaman_train)
model3_fit = model_spec3.fit()
model3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        17:35:14   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5882      3.580     11.897      0.000      35.551      49.626
# ...

# %% [markdown]
# The model's **R-squared** value is 0.148, meaning it explains only 14.8% of the variation in `HP`, which is quite low. This suggests other factors are affecting `HP` that aren’t captured by the model. The **Adjusted R-squared** is slightly lower at 0.143, indicating that adding more predictors doesn’t significantly improve the model's explanatory power.
#
# The **coefficients** show that:
# - The **Intercept** is 42.5882, meaning the baseline `HP` when both `Attack` and `Defense` are zero is 42.5882.
# - For **Attack**, each additional unit increases `HP` by 0.2472. This predictor is statistically significant with a very low p-value (0.000).
# - For **Defense**, each additional unit increases `HP` by 0.1001, and it’s also statistically significant with a p-value of 0.028.
#
# Both **Attack** and **Defense** are statistically significant predictors of `HP`, but the low R-squared value shows the model doesn’t explain a lot of the variation in `HP`, indicating there might be other important factors missing from the model.

# %% [markdown]
# ## Cell 3
#
# This step calculates both the **"in sample"** and **"out of sample"** R-squared values to compare the model’s performance.
#
# 1. **Prediction on Test Data**: The model generates predictions for the test data (`pokeaman_test`), representing how well it predicts unseen `HP` values.
#
# 2. **"In sample" R-squared**: This value is calculated from the training data (`pokeaman_train`) and measures how well the model fits the training data. It was previously found to be 0.148.
#
# 3. **"Out of sample" R-squared**: This is calculated by comparing the predicted values to the actual `HP` values in the test data. It shows how well the model generalizes to new data.
#
# 4. **Print Statements**: The first prints the "in sample" R-squared, and the second prints the "out of sample" R-squared.
#
# ### Purpose:
# This step helps assess the model’s performance by comparing its fit to the training data ("in sample") versus how well it generalizes to new data ("out of sample"). A large difference between the two could indicate overfitting.

# %%
yhat_model3 = model3_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model3_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model3)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.14771558304519894
# 'Out of sample' R-squared: 0.21208501873920738

# %% [markdown]
# 1. **In sample R-squared**: 0.1477 — The model explains about 14.77% of the variation in `HP` for the training data, which reflects a relatively poor fit.
#
# 2. **Out of sample R-squared**: 0.2121 — The model explains about 21.21% of the variation in `HP` for the test data, which is better than its fit to the training data.
#
# ### Takeaway:
# - The **out of sample** R-squared is higher than the **in sample** R-squared, which is unusual. Typically, we'd expect worse performance on unseen data if the model is overfitting. However, in this case, it suggests the model might generalize better than it fits the training data, potentially due to issues with the representativeness of the training set or other influencing factors.

# %% [markdown]
# ## Cell 4
#
# This cell sets up and fits a **multiple linear regression model** that includes **interaction terms** between predictors:
#
# 1. **Formula**:
#    - The model is specified with several predictors (`Attack`, `Defense`, `Speed`, etc.) and their **interaction effects** (e.g., how `Attack` and `Defense` jointly affect `HP`).
#    - The `Q()` function ensures that variables with special characters (like `Sp. Def` and `Sp. Atk`) are properly interpreted.
#    - The commented-out part would add complex interactions for categorical variables, but it's avoided due to the large number of combinations that could make the model too complex.
#
# 2. **Model Specification**:
#    - The model is created using `ols()` from **statsmodels**, which fits an ordinary least squares regression.
#
# 3. **Model Fitting**:
#    - `model4_spec.fit()` fits the model to the training data.
#
# 4. **Model Summary**:
#    - `model4_fit.summary()` provides detailed output, including coefficients and diagnostic statistics.
#
# ### Purpose:
# - This model aims to capture more complex relationships by including both main effects and interactions between predictors, offering a more flexible fit for `HP`.

# %%
model4_linear_form = 'HP ~ Attack * Defense * Speed * Legendary'
model4_linear_form += ' * Q("Sp. Def") * Q("Sp. Atk")'
# DO NOT try adding '* C(Generation) * C(Q("Type 1")) * C(Q("Type 2"))'
# That's 6*18*19 = 6*18*19 possible interaction combinations...
# ...a huge number that will blow up your computer

model4_spec = smf.ols(formula=model4_linear_form, data=pokeaman_train)
model4_fit = model4_spec.fit()
model4_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     4.764
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           4.23e-21
# Time:                        17:35:14   Log-Likelihood:                -1738.6
# No. Observations:                 400   AIC:                             3603.
# Df Residuals:                     337   BIC:                             3855.
# Df Model:                          62
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# - **Overfitting Risk**: The model is likely overfitting the training data due to its complexity. It includes a large number of predictors (62 coefficients) and interaction terms that may capture noise rather than true relationships. A significant increase in R² could mean the model is capturing more nuances in the training data, but it could also mean it's overfitting to noise or specific patterns that won’t generalize well to new data.
#
# - **Key Indicators**:
#   - The model shows a large gap between **R-squared** (0.467) and **Adjusted R-squared** (0.369), suggesting the added complexity isn't improving the model's generalizability.
#   - Many predictors, including interaction terms, are statistically significant, but these relationships may not be meaningful beyond the training data.
#   - High **AIC** and **BIC** values (3603 and 3855) also signal that the model might be too complex.
#
# - **Possible Solutions**:
#   - **Cross-validation** can help assess the model's performance on unseen data.
#   - Reducing the number of predictors, particularly interactions, could simplify the model and improve its ability to generalize.

# %% [markdown]
# ## Cell 5
#
# ### In-sample vs Out-of-sample R-squared:
# - **In-sample R²** tells you how well the model fits the training data.
# - **Out-of-sample R²** tells you how well the model generalizes to unseen data (test set).
#
# ### Key Insights:
# - **High In-sample R² vs Low Out-of-sample R²** suggests **overfitting**, where the model fits the training data well but struggles with new data.
# - **Similar High R² values** in both in-sample and out-of-sample suggest the model generalizes well without overfitting.
#
# If there's a large difference between in-sample and out-of-sample R², the model might be overfitting and could benefit from simplification or regularization.

# %%
yhat_model4 = model4_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model4_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model4)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.46709442115833855
# 'Out of sample' R-squared: 0.002485342598992873

# %% [markdown]
# The stark contrast between the **in-sample** (0.4671) and **out-of-sample** (0.0025) R-squared values indicates a clear **overfitting** issue:
#
# ### Key Points:
# - **In-sample R-squared (0.4671)**: The model explains about **47%** of the variance in the training data, which is a moderate fit.
# - **Out-of-sample R-squared (0.0025)**: The model performs poorly on the test set, explaining almost no variance. This suggests that it has **failed to generalize** to new data.
#
# ### Conclusion:
# - The **large discrepancy** between the in-sample and out-of-sample R² values points to **overfitting**. The model is too closely fitted to the training data, capturing noise or specific patterns that don’t generalize to unseen data.

# %% [markdown]
# __
# ### Conclusion:
#
# We fitted a linear regression model to the dataset and evaluated its performance both on the training data and test data:
#
# 1. **Model Fitting and Evaluation**: The model explained about 46.7% of the variance in the training data, suggesting a reasonable fit to the training data.
#
# 2. **Prediction and Comparison**: The out-of-sample R-squared on the test data was only 0.0025, indicating that the model failed to generalize well to unseen data.
#
# 3. **Identifying Overfitting**: The large difference between in-sample and out-of-sample R-squared values points to overfitting, where the model fits the training data well but fails to predict new data accurately.
#
# 4. **Implications of Overfitting**: The model's poor test performance suggests it has too many parameters or is overly complex, making it ineffective for new data.
#
# 5. **Next Steps**: To address overfitting, we could simplify the model, increase the dataset size, or use techniques like regularization and cross-validation.
#
# ### Final Thoughts:
# Although the model fits the training data well, its poor performance on test data shows a need for adjustments to improve its ability to generalize to new data.

# %% [markdown]
# __
# ## ChatGPT Session Summary
# https://chatgpt.com/share/6736cd29-bda4-800e-b950-910bed1501c8
#
# In our exchanges, we explored the process of fitting a linear regression model to a dataset and evaluating its performance using both in-sample and out-of-sample R-squared values. The in-sample R-squared value (0.467) initially suggested that the model explained a decent portion of the variance within the training data. However, when tested on the out-of-sample data, the R-squared value dropped drastically to approximately 0.0025, which indicated that the model was not generalizing well to new, unseen data. This significant disparity between the in-sample and out-of-sample R-squared values is a classic sign of overfitting, where the model is overly complex and captures noise in the training data rather than the true underlying relationships. We discussed potential solutions to improve the model's generalization, such as simplifying the model, utilizing cross-validation to better assess performance, and increasing the size of the training dataset. This analysis highlighted the importance of balancing model complexity and the ability to generalize to ensure better performance on unseen data.
#
# ___

# %% [markdown]
# # 6.

# %%
# "Cond. No." WAS 343.0 WITHOUT to centering and scaling
model3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        17:35:14   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5882      3.580     11.897      0.000      35.551      49.626
# ...

# %%
from patsy import center, scale

model3_linear_form_center_scale = \
  'HP ~ scale(center(Attack)) + scale(center(Defense))' 
model_spec3_center_scale = smf.ols(formula=model3_linear_form_center_scale,
                                   data=pokeaman_train)
model3_center_scale_fit = model_spec3_center_scale.fit()
model3_center_scale_fit.summary()
# "Cond. No." is NOW 1.66 due to centering and scaling
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.66e-14
# Time:                        17:35:15   Log-Likelihood:                -1832.6
# No. Observations:                 400   AIC:                             3671.
# Df Residuals:                     397   BIC:                             3683.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
model4_linear_form_CS = 'HP ~ scale(center(Attack)) * scale(center(Defense))'
model4_linear_form_CS += ' * scale(center(Speed)) * Legendary' 
model4_linear_form_CS += ' * scale(center(Q("Sp. Def"))) * scale(center(Q("Sp. Atk")))'
# Legendary is an indicator, so we don't center and scale that

model4_CS_spec = smf.ols(formula=model4_linear_form_CS, data=pokeaman_train)
model4_CS_fit = model4_CS_spec.fit()
model4_CS_fit.summary().tables[-1]  # Cond. No. is 2,250,000,000,000,000

# The condition number is still bad even after centering and scaling
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Just as the condition number was very bad to start with
model4_fit.summary().tables[-1]  # Cond. No. is 12,000,000,000,000,000
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Explanation of Analysis
#
# The complexity of `model4_linear_form` leads to a **design matrix** called `model4_spec.exog`, which contains a large number of predictor variables that are highly correlated with each other. This multicollinearity, as reflected by a high **condition number**, contributes to **overfitting** in `model4_fit` and reduces its ability to generalize effectively to new, unseen data.
#
# Here’s a breakdown of how this unfolds:
#
# - The **design matrix** (`model4_spec.exog`) consists of the predictor variables used in the model. The dimensions of this matrix, which can be found using `model4_spec.exog.shape`, reveal the number of predictors created by the complex specification of `model4_linear_form`.
#
# - **Multicollinearity** happens when predictor variables are highly correlated with each other, making it difficult to separate their individual contributions to the outcome. This can be observed by calculating the correlation coefficients between the columns of the design matrix using `np.corrcoef(model4_spec.exog)`.
#
# - A key diagnostic tool for identifying multicollinearity is the **condition number** of the design matrix. A **large condition number** suggests that the predictor variables are strongly correlated with each other. Although the exact condition number for `model4_spec.exog` is not provided, the sources emphasize that `model4_fit` has a **"very (VERY) large" condition number**, even after centering and scaling the continuous predictors. This indicates severe multicollinearity.
#
# - **Multicollinearity creates instability** in the model because small changes in the data can result in disproportionately large changes in the estimated coefficients. This instability makes it hard to isolate the unique effects of each predictor variable on the outcome, leading to unreliable and uncertain predictions.
#
# - The high multicollinearity in `model4_fit`, coupled with the model’s complexity, leads to **overfitting**. Overfitting occurs when a model fits the **noise** and specific details of the training data rather than capturing the broader, more generalizable patterns. As a result, although `model4_fit` may perform well on the training data, it fails to generalize well to new, unseen data.
#
# ### In summary:
# The complex `model4_linear_form` results in a **design matrix** with numerous highly correlated predictor variables, which leads to multicollinearity. This, as indicated by a high condition number, causes **overfitting**, making it difficult for `model4_fit` to generalize to new data.

# %% [markdown]
# __
#
# ## NotebookLM Session Summary
#
# Our conversation explored why the complex `model4_linear_form` struggles to generalize effectively to new data. This complexity leads to a high number of predictor variables in the design matrix (`model4_spec.exog`), as indicated by its dimensions (`model4_spec.exog.shape`). These numerous predictors are highly correlated (**multicollinearity**), potentially observable through `np.corrcoef(model4_spec.exog)`, though the sources don't explicitly provide these coefficients.  A large **condition number** for `model4_fit`, even after centering and scaling continuous predictors, further substantiates the presence of significant multicollinearity. This means that the predictor variables provide redundant information, making it difficult to isolate their individual effects on the outcome variable. Consequently, small changes in the training data can lead to drastic shifts in the estimated coefficients.
#
# This multicollinearity, compounded by the model's complexity, leads to **overfitting**. The model becomes too attuned to the specific nuances of the training data (`model4_spec.endog`), learning the noise rather than the underlying patterns.  This overfitting is why `model4_fit` performs well on the training data but struggles to **generalize** to new, unseen data ("out-of-sample").  The discussion emphasizes a key concept: a complex model with highly correlated predictors often lacks the ability to accurately predict outcomes for data beyond the training set.
#
# ___

# %% [markdown]
# # 7. Extensions of Pokeaman Models

# %% [markdown]
# Consider the code below, which expands upon the previous pokeaman models.
#
# The following is my concise and brief interpretation (in alignment with the homework specifications).
#
#
# ### **Development from Model3_fit and Model4_fit to Model5_linear_form**
#
# **Model5** extends **Model3** and **Model4** by adding new predictors, including categorical variables such as **Generation** and **Type 1/Type 2** Pokémon. These variables are included to capture more complex relationships between the predictors and the outcome variable, HP. By introducing these predictors, Model5 aims to improve model performance.
#
# Looking at the results from **Model5**:
# - The **"in sample" R-squared** of **0.392** means the model explains about **39.2%** of the variance in HP. This is an improvement over earlier models.
# - The **"out of sample" R-squared** of **0.300** suggests the model explains only **30.0%** of the variance in unseen data, indicating a slight overfitting issue. Although the model captures relationships in the training set, it doesn’t generalize well to new data.
#
# Thus, while **Model5** includes more predictors, its slight drop in **out of sample** performance suggests room for improvement in terms of generalizability.
#
# ---
#
# ### **Development from Model5_linear_form to Model6_linear_form**
#
# Building on **Model5**, **Model6** introduces **indicator variables** for significant categorical predictors that were not fully captured in **Model5**. These include:
# - **Type 1** Pokémon: **Normal** and **Water**
# - **Generation**: **Generation 2** and **Generation 5**
#
# By adding these indicators, **Model6** attempts to refine the model and capture more specific, significant effects that **Model5** might not have fully addressed. The added variables aim to improve the prediction of HP by accounting for these specific categories.
#
# In **Model6**:
# - The **"in sample" R-squared** drops slightly to **0.332**, indicating that the additional indicators did not substantially improve the fit to the training data.
# - However, the **"out of sample" R-squared** is **0.296**, showing no significant change in the model's ability to generalize to new data compared to **Model5**.
#
# Therefore, while the inclusion of these indicators doesn't dramatically affect the model's overall performance, it doesn't cause a significant decline either, suggesting their impact is minimal.
#
# ---
#
# ### **Development from Model6_linear_form to Model7_linear_form**
#
# **Model7** extends **Model6** by adding **interaction terms** between the continuous predictors, such as **Attack**, **Speed**, **Sp. Def**, and **Sp. Atk**. The goal of these interaction terms is to capture more complex relationships between the predictors that might not be visible if treated separately.
#
# In **Model7**:
# - The **"in sample" R-squared** increases to **0.378**, showing a better fit to the training data compared to **Model6**.
# - The **"out of sample" R-squared** improves to **0.350**, indicating that the model has improved generalizability compared to **Model6**, which had a lower **out of sample** R-squared of **0.296**.
#
# Thus, **Model7** benefits from the addition of interaction terms. However, multicollinearity was a significant issue, as indicated by an extremely high condition number of approximately **2.34 trillion**. This arose because interaction terms were added without centering and scaling the continuous predictors, leading to unstable coefficients and a lack of reliability when generalizing to new data.
#
# To address this, Model 7 was transformed into **Model 7_CS**.
#
# This highlights the importance of addressing multicollinearity in models with interaction terms to ensure stability and reliability.
#
# ---
#
# ### **Centering and Scaling for Model7_CS**
#
# In **Model7_CS**, the continuous variables are **centered and scaled**, or standardized, to reduce multicollinearity and improve model stability. The **Condition Number (Cond. No.)** is significantly reduced from **2.34e+09** in **Model7** to **15.4** in **Model7_CS**, suggesting that multicollinearity is no longer a significant issue. A **Condition Number** below **30** typically indicates a stable model with low multicollinearity.
#
# By standardizing the variables, **Model7_CS** eliminates some of the collinearity between predictors, enhancing model reliability.
#
# ---
#
# ### **Summary and Conclusion**
#
# 1. **Model5** added more predictors, including categorical variables like **Generation** and **Type 1/Type 2** Pokémon. While the **"in-sample" R-squared** improved, the **"out-of-sample" R-squared** decreased, suggesting some overfitting.
# 2. **Model6** refined the model by adding indicator variables for specific Pokémon types and generations. These variables had a minimal impact on performance, with no significant improvement in **in-sample** or **out-of-sample** R-squared.
# 3. **Model7** introduced interaction terms between continuous predictors, improving both **in-sample** and **out-of-sample** R-squared. This addition helped capture synergies between predictors, leading to better overall model performance.
# 4. **Model7_CS** standardized the continuous variables, reducing the **Condition Number** and mitigating multicollinearity, resulting in a more stable and reliable model.
#
# In conclusion, **Model7_CS** is the most reliable and generalizable model, balancing performance with stability. The inclusion of interaction terms and scaling led to significant improvements, making it the final choice for further analysis.

# %%
# Here's something a little more reasonable...
model5_linear_form = 'HP ~ Attack + Defense + Speed + Legendary'
model5_linear_form += ' + Q("Sp. Def") + Q("Sp. Atk")'
model5_linear_form += ' + C(Generation) + C(Q("Type 1")) + C(Q("Type 2"))'

model5_spec = smf.ols(formula=model5_linear_form, data=pokeaman_train)
model5_fit = model5_spec.fit()
model5_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     4.948
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           9.48e-19
# Time:                        17:35:15   Log-Likelihood:                -1765.0
# No. Observations:                 400   AIC:                             3624.
# Df Residuals:                     353   BIC:                             3812.
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
yhat_model5 = model5_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model5_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model5)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.3920134083531893
# 'Out of sample' R-squared: 0.30015614488652215

# %%
# Here's something a little more reasonable...
model6_linear_form = 'HP ~ Attack + Speed + Q("Sp. Def") + Q("Sp. Atk")'
# And here we'll add the significant indicators from the previous model
# https://chatgpt.com/share/81ab88df-4f07-49f9-a44a-de0cfd89c67c
model6_linear_form += ' + I(Q("Type 1")=="Normal")'
model6_linear_form += ' + I(Q("Type 1")=="Water")'
model6_linear_form += ' + I(Generation==2)'
model6_linear_form += ' + I(Generation==5)'

model6_spec = smf.ols(formula=model6_linear_form, data=pokeaman_train)
model6_fit = model6_spec.fit()
model6_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     24.36
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.25e-30
# Time:                        17:35:15   Log-Likelihood:                -1783.6
# No. Observations:                 400   AIC:                             3585.
# Df Residuals:                     391   BIC:                             3621.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
yhat_model6 = model6_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model6_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.3326310334310908
# 'Out of sample' R-squared: 0.29572460427079933

# %%
# And here's a slight change that seems to perhaps improve prediction...
model7_linear_form = 'HP ~ Attack * Speed * Q("Sp. Def") * Q("Sp. Atk")'
model7_linear_form += ' + I(Q("Type 1")=="Normal")'
model7_linear_form += ' + I(Q("Type 1")=="Water")'
model7_linear_form += ' + I(Generation==2)'
model7_linear_form += ' + I(Generation==5)'

model7_spec = smf.ols(formula=model7_linear_form, data=pokeaman_train)
model7_fit = model7_spec.fit()
model7_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     12.16
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           4.20e-29
# Time:                        17:35:15   Log-Likelihood:                -1769.5
# No. Observations:                 400   AIC:                             3579.
# Df Residuals:                     380   BIC:                             3659.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
yhat_model7 = model7_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model7_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2)
# Out:
# 'In sample' R-squared:     0.37818209127432456
# 'Out of sample' R-squared: 0.35055389205977444

# %%
# And here's a slight change that seems to perhas improve prediction...
model7_linear_form_CS = 'HP ~ scale(center(Attack)) * scale(center(Speed))'
model7_linear_form_CS += ' * scale(center(Q("Sp. Def"))) * scale(center(Q("Sp. Atk")))'
# We DO NOT center and scale indicator variables
model7_linear_form_CS += ' + I(Q("Type 1")=="Normal")'
model7_linear_form_CS += ' + I(Q("Type 1")=="Water")'
model7_linear_form_CS += ' + I(Generation==2)'
model7_linear_form_CS += ' + I(Generation==5)'

model7_CS_spec = smf.ols(formula=model7_linear_form_CS, data=pokeaman_train)
model7_CS_fit = model7_CS_spec.fit()
model7_CS_fit.summary().tables[-1] 
# "Cond. No." is NOW 15.4 due to centering and scaling
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# "Cond. No." WAS 2,340,000,000 WITHOUT to centering and scaling
model7_fit.summary().tables[-1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## ChatGPT Session Summary
# https://chatgpt.com/share/6736cd29-bda4-800e-b950-910bed1501c8
#
# In our discussions, we focused on developing and refining linear regression models 5, 6, and 7 to predict the `HP` variable from the Pokémon dataset. Model 5 was extended from earlier models by incorporating additional continuous and categorical predictors, including `Attack`, `Speed`, and `Generation`, resulting in a modest "in-sample" R-squared of 0.39 and an "out-of-sample" R-squared of 0.30. Model 6 further refined the predictors by adding significant indicator variables for `Type 1` and `Generation`, leading to slightly improved performance, with "in-sample" and "out-of-sample" R-squared values of 0.33 and 0.30, respectively. Model 7 introduced interaction terms between predictors, significantly increasing model complexity. However, it encountered severe multicollinearity issues, indicated by an unreasonably high condition number of 2.34 trillion. To address this, a new version, model 7_CS, was created by centering and scaling continuous predictors, which reduced the condition number to a more manageable 15.4, and led to improved stability in the model's predictions. We also evaluated model performance by comparing in-sample and out-of-sample R-squared values to assess generalizability and predictive power.
# ___

# %% [markdown]
# # 8. $R^2$ Comparisons

# %% [markdown]
# Consider the code and accompanying visualization below. The goal of the following code is to compare the In-Sample and Out of Sample $R^2$ by plotting them on a scatter plot (In-sample on the x-axis, Out of sample on the y-axis). Ideally, they should match, and thus fit on the y=x line. If they don't we may discuss the interpretations of this conclusion

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
import plotly.express as px
import plotly.graph_objects as go

# Assuming `pokeaman_train` and `pokeaman_test` are the datasets you're using
# Adjust this linear formula based on your model
linear_form = 'HP ~ Attack * Speed * Q("Sp. Def") * Q("Sp. Atk")'

# Prepare arrays to store R-squared values
reps = 100  # Number of repetitions for bootstrapping
in_sample_Rsquared = np.array([0.0] * reps)
out_of_sample_Rsquared = np.array([0.0] * reps)

# Loop to perform repeated train-test splits and model fitting
for i in range(reps):
    # Split the data 50-50 for training and testing
    pokeaman_train_split, pokeaman_test_split = train_test_split(pokeaman_train, train_size=0.5, random_state=None)
    
    # Fit the model on the training data
    final_model_fit = smf.ols(formula=linear_form, data=pokeaman_train_split).fit()
    
    # Store the in-sample R-squared value
    in_sample_Rsquared[i] = final_model_fit.rsquared
    
    # Store the out-of-sample R-squared value using correlation of predicted values
    out_of_sample_Rsquared[i] = np.corrcoef(pokeaman_test_split['HP'], 
                                            final_model_fit.predict(pokeaman_test_split))[0, 1] ** 2

# Create a DataFrame to store the results
df = pd.DataFrame({
    "In Sample Performance (Rsquared)": in_sample_Rsquared,
    "Out of Sample Performance (Rsquared)": out_of_sample_Rsquared
})

# Visualize the results using Plotly
fig = px.scatter(df, x="In Sample Performance (Rsquared)", y="Out of Sample Performance (Rsquared)")

fig.update_layout(
    title="In Sample Performance vs. Out of Sample Performance (Rsquared)",
    showlegend=True,
    width=800,
    height=500
)

fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], name="y=x", line_shape='linear'))

# Update the actual data points trace to show it in the legend with a specific label
fig.data[0].name = 'Data Points'
fig.data[0].showlegend = True  # Ensure the data points are included in the legend
fig.data[0].marker = dict(color='blue', size=5, symbol='circle')  # Customize the marker for legend



fig.show(renderer='png')

# %% [markdown]
# ## Findings
#
# #### **Re-thinking the situation:**
# When we observe that **in-sample R²** is higher than **out-of-sample R²**, and the points are clustered below the y=x line, it suggests **overfitting**. This means the model is too complex for the data, capturing noise or spurious patterns specific to the training set but not generalizing well to new, unseen data.
#
# #### **Why does overfitting happen?**
# Overfitting happens when the model becomes too complex, which leads to it "learning" not just the true relationships between predictors and the outcome, but also the random fluctuations or peculiarities in the training data. As a result, it performs very well on the training data (high in-sample R²) but performs poorly on new data, leading to a lower out-of-sample R². The points falling below the y=x line further suggest that the model is struggling to make accurate predictions on new data.
#
# #### **What does this mean for the scatter plot?**
# In the scatter plot, if the points fall **below** the y=x line, it means the **out-of-sample R²** is lower than the **in-sample R²**. This is an indication that the model performs well on the training data but is unable to predict new data effectively. Since the model is too complex, it has memorized patterns specific to the training data that do not apply to new data. In other words, it's too "tuned" to the training set and unable to generalize.
#
# #### **What does this all point to?**
# When in-sample R² is consistently higher than out-of-sample R², and the points on the plot are below the y=x line, it points directly to overfitting. The model is **too complex**, capturing irrelevant details in the data that are specific to the training set. While the model fits the training data very well, it fails to generalize effectively to new data, which is why the out-of-sample R² is much lower.
#
# #### **Summary:**
# In summary, the findings indicate that the model is currently **overfitting** the data. The high in-sample R² compared to the lower out-of-sample R², combined with the scatter plot showing points below the y=x line, all suggest that the model is too complex and is fitting noise in the training data. To address this, simplifying the model, using cross-validation, applying regularization, and carefully selecting features would likely help improve the model’s ability to generalize to new data.
#
# Both in-sample and out of sample $R^2$ values are relatively low, but the out of sample model has a much lower $R^2$, indicating it does much worse at generalizing new data.

# %% [markdown]
# __
#
# ## ChatGPT Session Summary
# https://chatgpt.com/share/6736cd29-bda4-800e-b950-910bed1501c8
#
# In our analysis, we discussed the relationship between in-sample and out-of-sample R² values, focusing on how these metrics indicate model performance and generalizability. When in-sample R² is significantly higher than out-of-sample R², it often points to overfitting, where the model captures patterns specific to the training data but fails to generalize well to new, unseen data. For example, with model7_fit, we found that although the in-sample R² was relatively high, the out-of-sample R² dropped substantially when tested on Generation 1 data, suggesting overfitting. This discrepancy highlights the trade-off between model complexity and generalizability, as more complex models may perform better on the training data but fail to predict accurately on future data. The result emphasizes the importance of considering generalizability when building predictive models and suggests that simpler models might provide better, more consistent performance on new data, even if they slightly underperform in terms of in-sample accuracy.
# ___

# %% [markdown]
# # 9. Further Model Comparisons — Performance and Interpretability

# %% [markdown]
# Consider the following four cells of code, which expands on the previous pokeaman models. I'll explain each cell sequentially, then provide a concluding interpretation of the findings.

# %% [markdown]
# ## Cell 1
#
# ### Summary of Results:
#
# - **In-sample R² (original):** 0.378 — This means the model explains 37.8% of the variance in the training data, indicating a moderate fit.
# - **Out-of-sample R² (original):** 0.351 — The model performs slightly worse on the test data, explaining 35.1% of the variance. While there is a slight difference, it suggests that the model is reasonably generalizing to new data.
# - **In-sample R² (Generation 1):** 0.573 — The model performs better when trained only on Generation 1 data, explaining 57.3% of the variance and showing a good fit on this subset.
# - **Out-of-sample R² (Generation 1):** 0.112 — However, the performance on data from other generations is poor, explaining just 11.2% of the variance. This large gap suggests significant overfitting, meaning the model is too specialized to the Generation 1 data.
#
# ### Conclusion:
# The model trained only on Generation 1 data suffers from **overfitting**. While it performs well on the data it was trained on (Generation 1), it fails to generalize to new data from other generations. On the other hand, the original model shows a better balance, with reasonable performance across both in-sample and out-of-sample data, suggesting it generalizes better overall.

# %%
model7_gen1_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model7_gen1_predict_future_fit = model7_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model7_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.35055389205977444 (original)
# 'In sample' R-squared:     0.5726118179916575 (gen1_predict_future)
# 'Out of sample' R-squared: 0.11151363354803218 (gen1_predict_future)

# %% [markdown]
# ## Cell 2
#
# The results show that the model trained on Generations 1–5 has a slightly better fit to the training data compared to the original model. Its in-sample R² is 0.3905, a small improvement over the original model's 0.3782. However, the model's out-of-sample R² drops significantly to 0.2339, compared to the original model's 0.3506. This sharp decline in out-of-sample performance indicates that the model struggles to generalize to new data, specifically from Generation 6.
#
# The large gap between the in-sample and out-of-sample R² values suggests overfitting: the model fits the training data well but doesn't predict new, unseen data as effectively. Essentially, it has likely picked up patterns unique to Generations 1–5, which do not carry over to Generation 6 data. This highlights that the model may not be robust enough to make reliable predictions for future or out-of-sample data.

# %%
model7_gen1to5_predict_future = smf.ols(formula=model7_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model7_gen1to5_predict_future_fit = model7_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model7_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model7)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model7_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model7_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.37818209127432456 (original)
# 'Out of sample' R-squared: 0.35055389205977444 (original)
# 'In sample' R-squared:     0.3904756578094535 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.23394915464343125 (gen1to5_predict_future)

# %% [markdown]
# __
# ## Cell 3
#
#
# The drop in out-of-sample R² from 0.2957 to 0.1933 suggests that **model6** is struggling to generalize to new, unseen data. Although its in-sample R² improved from 0.3326 to 0.4434, which indicates better fit to the training set, the much lower out-of-sample R² points to **overfitting**. The model is performing well on the training data, but this success doesn’t translate to new data, suggesting the model has become too specialized in fitting the training set. Instead of learning the broader, underlying patterns in the data, it seems to have learned specific details that don’t apply to unseen examples.
#
# In summary, the model’s significant drop in out-of-sample performance highlights overfitting, where the model captures noise or unnecessary detail from the training set that hinders its ability to generalize.

# %%
model6_gen1_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation==1])
model6_gen1_predict_future_fit = model6_gen1_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1_predict_future_fit.rsquared, "(gen1_predict_future)")
y = pokeaman[pokeaman.Generation!=1].HP
yhat = model6_gen1_predict_future_fit.predict(pokeaman[pokeaman.Generation!=1])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.29572460427079933 (original)
# 'In sample' R-squared:     0.4433880517727282 (gen1_predict_future)
# 'Out of sample' R-squared: 0.1932858534276128 (gen1_predict_future)

# %% [markdown]
# __
#
# ## Cell 4
#
#
# In this case, the in-sample R² for **model6** remains relatively stable, moving from 0.3326 to 0.3352, indicating consistent performance on the training data. However, the out-of-sample R² shows a slight drop from 0.2957 to 0.2626 when excluding Generation 6 from the training set. This suggests that the model doesn’t perform as well when tasked with predicting future data (i.e., Generation 6) that differs from the training data, though the decline isn’t as steep as in earlier models.
#
# Overall, the results point to **mild overfitting**. The model explains the training data well (higher in-sample R²), but it’s not as effective at generalizing to new data (lower out-of-sample R²). The relatively small differences in R² values imply that the model is somewhat overfitted, but not excessively so. It is certainly an improvement to the previous models/generations, but there is still a lack of generalizability here (this might just be a consequence of Gen 1-5 representing the overall sample better with model 6).

# %%
model6_gen1to5_predict_future = smf.ols(formula=model6_linear_form,
                                   data=pokeaman[pokeaman.Generation!=6])
model6_gen1to5_predict_future_fit = model6_gen1to5_predict_future.fit()
print("'In sample' R-squared:    ", model6_fit.rsquared, "(original)")
y = pokeaman_test.HP
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model6)[0,1]**2, "(original)")
print("'In sample' R-squared:    ", model6_gen1to5_predict_future_fit.rsquared, "(gen1to5_predict_future)")
y = pokeaman[pokeaman.Generation==6].HP
yhat = model6_gen1to5_predict_future_fit.predict(pokeaman[pokeaman.Generation==6])
print("'Out of sample' R-squared:", np.corrcoef(y,yhat)[0,1]**2, "(gen1to5_predict_future)")
# Out:
# 'In sample' R-squared:     0.3326310334310908 (original)
# 'Out of sample' R-squared: 0.29572460427079933 (original)
# 'In sample' R-squared:     0.33517279824114776 (gen1to5_predict_future)
# 'Out of sample' R-squared: 0.26262690178799936 (gen1to5_predict_future)

# %% [markdown]
# ## Conclusion
#
# After analyzing the four cells, we consistently observed signs of **overfitting**. All models showed a noticeably higher in-sample $R^2$ compared to out-of-sample $R^2$, indicating strong performance on the training data but poor generalization to new, unseen data. This suggests that the models may have been too complex or too finely tuned to the training data, capturing patterns that didn’t extend well to other generations.
#
# The disparity between in-sample and out-of-sample $R^2$ was most pronounced when testing on Generation 6 data or other excluded subsets, reinforcing the lack of generalizability. This highlights the challenge of model complexity: a high $R^2$ on the training data often signals overfitting when it doesn't translate to improved performance on new data.
#
# To address this issue, potential solutions include simplifying the models, applying regularization methods, or experimenting with different approaches that prioritize generalizability, leading to models better suited to unseen data.

# %% [markdown]
# __
# ## ChatGPT Session Summary
# https://chatgpt.com/share/6736cd29-bda4-800e-b950-910bed1501c8
#
# In our analysis, we examined the predictive performance of multiple models by comparing in-sample and out-of-sample R² values for different subsets of the data. We observed that the in-sample R² was consistently higher than the out-of-sample R², suggesting potential **overfitting**. This indicated that the models were tailored too specifically to the training data, leading to strong performance within the training set but poor generalization to unseen data. Although underfitting was initially considered, the main issue identified was overfitting, as the models struggled to predict new data accurately. These findings emphasize the need to improve generalization by possibly simplifying the models or employing techniques such as regularization or cross-validation to avoid overfitting and enhance predictive accuracy.
